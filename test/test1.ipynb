# %%
import leafmap
m = leafmap.Map(center=(40, -100), zoom=4)
m
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import leafmap
# ----> 2 m = leafmap.Map(center=(40, -100), zoom=4)
#       3 m
#
# File /usr/local/lib/python3.10/site-packages/leafmap/leafmap.py:87, in Map.__init__(self, **kwargs)
#      85     kwargs["fullscreen_control"] = True
#      86 if kwargs["fullscreen_control"]:
# ---> 87     self.add(ipyleaflet.FullScreenControl())
#      89 if "search_control" not in kwargs:
#      90     kwargs["search_control"] = True
#
# AttributeError: 'Map' object has no attribute 'add'
